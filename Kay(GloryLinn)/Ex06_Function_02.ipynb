# %% [markdown]
# <a href="https://colab.research.google.com/github/gloryprospect39-blip/MMDT_T-PY101_Batch03/blob/main/Kay(GloryLinn)/Ex06_Function_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Exercises cover both Exception Handling and variable scopes.

# %% [markdown]
# ### Q1) Run the following programs, identify and Fix the errors.
# Use **exception handling** approach to handle the erros.

# %%
#Q1.1) Zero division error
def myfunction(a,b):
    answer = a/b
    return answer


#Call the function as follows:
myfunction(2,0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-2152702972.py in <cell line: 0>()
#       6
#       7 #Call the function as follows:
# ----> 8 myfunction(2,0)
#
# /tmp/ipython-input-2152702972.py in myfunction(a, b)
#       1 #Q1.1) Zero division error
#       2 def myfunction(a,b):
# ----> 3     answer = a/b
#       4     return answer
#       5
#
# ZeroDivisionError: division by zero

# %%
# Q1.1) Zero division error
def myfunction(a, b):
    try:
        answer = a / b
        return answer
    except ZeroDivisionError:
        return "Error: Division by zero is not allowed."

# Call the function
print(myfunction(2, 0))
# Out:
# Error: Division by zero is not allowed.

# %%
#Q1.2 Name Error

def myfunction2(c):
    answer = a/c
    return answer


# Call the function as follows:
myfunction2(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1283999828.py in <cell line: 0>()
#       7
#       8 # Call the function as follows:
# ----> 9 myfunction2(3)
#
# /tmp/ipython-input-1283999828.py in myfunction2(c)
#       2
#       3 def myfunction2(c):
# ----> 4     answer = a/c
#       5     return answer
#       6
#
# NameError: name 'a' is not defined

# %%
# Q1.2 Name Error
def myfunction2(a, c):
    answer = a / c
    return answer

# Call the function
print(myfunction2(6, 3))
# Out:
# 2.0

# %%
#Q1.3 IndexError
def myfunction3(b):
    mylist = [2, 3, 5, -7, 8, 0]
    idx = 0
    while idx<=6:
        print('Iteration:', idx, mylist[idx]/b)
        idx = idx+1
        print('Iteration completed')

# Call the function as follows:
myfunction3(b=5)
# Out:
# Iteration: 0 0.4
# Iteration completed
# Iteration: 1 0.6
# Iteration completed
# Iteration: 2 1.0
# Iteration completed
# Iteration: 3 -1.4
# Iteration completed
# Iteration: 4 1.6
# Iteration completed
# Iteration: 5 0.0
# Iteration completed
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-445817610.py in <cell line: 0>()
#       9
#      10 # Call the function as follows:
# ---> 11 myfunction3(b=5)
#
# /tmp/ipython-input-445817610.py in myfunction3(b)
#       4     idx = 0
#       5     while idx<=6:
# ----> 6         print('Iteration:', idx, mylist[idx]/b)
#       7         idx = idx+1
#       8         print('Iteration completed')
#
# IndexError: list index out of range

# %%
# Q1.3 IndexError
def myfunction3(b):
    mylist = [2, 3, 5, -7, 8, 0]
    idx = 0
    while idx < len(mylist):   # fix here
        print('Iteration:', idx, mylist[idx] / b)
        idx = idx + 1
        print('Iteration completed')

# Call the function
myfunction3(b=5)
# Out:
# Iteration: 0 0.4
# Iteration completed
# Iteration: 1 0.6
# Iteration completed
# Iteration: 2 1.0
# Iteration completed
# Iteration: 3 -1.4
# Iteration completed
# Iteration: 4 1.6
# Iteration completed
# Iteration: 5 0.0
# Iteration completed

# %%
#Q1.4 Zero Division Error, Value Error
def divide(a, b):
    result = a / b
    print('The result of division is', result)
    # FIX THE ERROR BELOW
    # ZeroDivisionError
    # ValueError
    return result


# Call the function as follows:
divide("10",2)
divide(10,0)
divide(10, "two")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3960857325.py in <cell line: 0>()
#      10
#      11 # Call the function as follows:
# ---> 12 divide("10",2)
#      13 divide(10,0)
#      14 divide(10, "two")
#
# /tmp/ipython-input-3960857325.py in divide(a, b)
#       1 #Q1.4 Zero Division Error, Value Error
#       2 def divide(a, b):
# ----> 3     result = a / b
#       4     print('The result of division is', result)
#       5     # FIX THE ERROR BELOW
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
# Q1.4 Zero Division Error, Value Error
def divide(a, b):
    try:
        a = float(a)   # convert to number
        b = float(b)
        result = a / b
        print('The result of division is', result)
        return result

    except ZeroDivisionError:
        print("Error: Cannot divide by zero.")

    except ValueError:
        print("Error: Please enter numeric values only.")

    except TypeError:
        print("Error: Invalid data type.")

# Call the function
divide("10", 2)
divide(10, 0)
divide(10, "two")
# Out:
# The result of division is 5.0
# Error: Cannot divide by zero.
# Error: Please enter numeric values only.

# %%
#Q1.5 FileNotFoundError
def read_file(filename):
    with open(filename, 'r') as file1:
        word_string = file1.read()
    print("File reading completed successfully")
    # FIX THE ERROR BELOW
    # FileNotFoundError
    return word_string


# Call the function as follows:
read_file("Q1.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2141363295.py in <cell line: 0>()
#      10
#      11 # Call the function as follows:
# ---> 12 read_file("Q1.txt")
#
# /tmp/ipython-input-2141363295.py in read_file(filename)
#       1 #Q1.5 FileNotFoundError
#       2 def read_file(filename):
# ----> 3     with open(filename, 'r') as file1:
#       4         word_string = file1.read()
#       5     print("File reading completed successfully")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Q1.txt'

# %%
# Q1.5 FileNotFoundError
def read_file(filename):
    try:
        with open(filename, 'r') as file1:
            word_string = file1.read()
        print("File reading completed successfully")
        return word_string

    except FileNotFoundError:
        print("Error: File not found. Please check the filename or path.")
        return None

# Call the function
read_file("Q1.txt")
# Out:
# Error: File not found. Please check the filename or path.

# %% [markdown]
# ### Q2) Run the following programs and fix the errors.
# Check the scopes of the variable, and fix it.

# %%
def check_rows(grid, expected_numbers):
    """Checks for uniqueness and completeness (1-9) in every row."""
    for i, row in enumerate(grid):
        if set(row) != expected_numbers:
            return False, f"Row {i + 1}: {row}"
    return True, None

def check_cols(grid, expected_numbers):
    """Checks for uniqueness and completeness (1-9) in every column."""
    sudoku_size = 6
    for j in range(sudoku_size):
        column = [grid[i][j] for i in range(sudoku_size)]
        if set(column) != expected_numbers:
            return False, f"Column {j + 1}: {column}"
    return True, None

def check_blocks(grid, expected_numbers):
    """Checks for uniqueness and completeness (1-9) in every 3x3 block."""
    # Iterate over the starting indices for the 9 blocks: (0,0), (0,3), (0,6), (3,0), ...
    for block_row_start in [0, 3, 6]:
        for block_col_start in [0, 3, 6]:
            block = []

            # Extract the 3x3 block's elements
            for i in range(block_row_start, block_row_start + 3):
                for j in range(block_col_start, block_col_start + 3):
                    block.append(grid[i][j])

            # Check for uniqueness and completeness (1-9)
            if set(block) != expected_numbers:
                return False, f"Block at ({block_row_start+1}, {block_col_start+1})"
    return True, None

def is_sudoku_solved(grid):
    """
    Checks if the given 9x9 grid is a correctly solved Sudoku puzzle by verifying
    row, column, and 3x3 block constraints.
    """
    global sudoku_size
    sudoku_size = len(grid)
    # 1. Basic check: Ensure the grid is 9x9
    if len(grid) != 9 or any(len(row) != 9 for row in grid):
        print("Error: Grid must be exactly 9x9.")
        return False

    # The set of expected numbers for a solved unit (row, column, or block)
    expected_numbers = set(range(1, 10))

    # 2. Check Rows
    is_valid, error_info = check_rows(grid, expected_numbers)
    if not is_valid:
        print(f"Mistake found in {error_info}")
        return False

    # 3. Check Columns
    is_valid, error_info = check_cols(grid, expected_numbers)
    if not is_valid:
        print(f"Mistake found in {error_info}")
        return False

    # 4. Check Blocks
    is_valid, error_info = check_blocks(grid, expected_numbers)
    if not is_valid:
        print(f"Mistake found in {error_info}")
        return False

    # If all checks pass, the Sudoku is solved correctly
    return True

# calling the function as follows:

import numpy as np
grid = np.random.randint(1,10,(9,9))
print(grid)
is_sudoku_solved(grid.tolist())

solved_grid = [
    [5, 3, 4, 6, 7, 8, 9, 1, 2],
    [6, 7, 2, 1, 9, 5, 3, 4, 8],
    [1, 9, 8, 3, 4, 2, 5, 6, 7],
    [8, 5, 9, 7, 6, 1, 4, 2, 3],
    [4, 2, 6, 8, 5, 3, 7, 9, 1],
    [7, 1, 3, 9, 2, 4, 8, 5, 6],
    [9, 6, 1, 5, 3, 7, 2, 8, 4],
    [2, 8, 7, 4, 1, 9, 6, 3, 5],
    [3, 4, 5, 2, 8, 6, 1, 7, 9]
]
is_sudoku_solved(solved_grid)
# Out:
# [[8 5 3 7 1 2 8 5 7]
#  [7 8 2 7 4 3 5 3 5]
#  [5 8 6 3 3 1 9 2 5]
#  [3 2 8 4 3 6 4 1 2]
#  [6 9 9 9 5 5 4 8 6]
#  [4 4 2 1 8 5 5 5 5]
#  [8 7 3 1 9 1 3 9 3]
#  [1 4 8 6 9 2 1 2 1]
#  [8 2 5 3 1 9 4 9 5]]
# Mistake found in Row 1: [8, 5, 3, 7, 1, 2, 8, 5, 7]
# Mistake found in Column 1: [5, 6, 1, 8, 4, 7]
# False
