# %% [markdown]
# <a href="https://colab.research.google.com/github/gloryprospect39-blip/MMDT_T-PY101_Batch03/blob/main/Kay(GloryLinn)/Ex07_Debugging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Simple Debugging: This exercise test a debugging skill!

# %%
import numpy as np

# %%
# Q1) Dubug the error by adding print statements to your program.

#Step 1: generate a random number between 1 and 5
rand_num = np.random.random(1)

# Add print statment here to know the value of rand_num


# Step 2: This code should print 5 rows of 'Hello ' rand_num times. Each row should be on a new line. Fix it.

for i in range(5):
    print('Hello ' * int(rand_num))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3139436822.py in <cell line: 0>()
#       2
#       3 #Step 1: generate a random number between 1 and 5
# ----> 4 rand_num = np.random.random(1)
#       5
#       6 # Add print statment here to know the value of rand_num
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# Step 1: generate a random number between 1 and 5
rand_num = np.random.randint(1, 6)

# Debug print statement
print("Random number generated:", rand_num)

# Step 2: Print 5 rows of 'Hello ' rand_num times
for i in range(5):
    print('Hello ' * rand_num)
# Out:
# Random number generated: 2
# Hello Hello
# Hello Hello
# Hello Hello
# Hello Hello
# Hello Hello

# %%
### Q2) Write a program that generates 10000 random numbers between 1 and 100 [inclusive] and counts how many of them are multiples of 12.
# This program has errors, and the result differs from the expected. Debug the code.

count = 0
range_start = 1
range_end = 100
for i in range(range_end):
    num = np.random.randint(range_start, range_end+1)

    if num%12==0:
        count=count+1

print('Number of multiples of 12:', count)
# Out:
# Number of multiples of 12: 6

# %%
import numpy as np

count = 0
range_start = 1
range_end = 100
TOTAL_NUMBERS = 10000

for i in range(TOTAL_NUMBERS):
    num = np.random.randint(range_start, range_end + 1)

    if num % 12 == 0:
        count += 1

print('Number of multiples of 12:', count)
# Out:
# Number of multiples of 12: 811

# %%
#Q3) The following program should counts how many of the squares of the numbers from 1 to 100 end in 1.  (Example: 1,81,121).
# ## Debug the code.

def fun_square_count():
    num_list = np.arange(1,101)
    squred_num = [value**2 for value in num_list]
    count=0
    for num in squred_num:
        if(num//10 == 1):
            count +=1
    return count

result = fun_square_count()
print(f"Your result is {result}")

print(f"Expected result is {20}")
# Out:
# Your result is 1
# Expected result is 20

# %%
import numpy as np

def fun_square_count():
    num_list = np.arange(1, 101)
    squared_num = [value**2 for value in num_list]

    count = 0
    for num in squared_num:
        if num % 10 == 1:   # FIXED
            count += 1
    return count

result = fun_square_count()
print(f"Your result is {result}")
print(f"Expected result is {20}")
# Out:
# Your result is 20
# Expected result is 20

# %%
#Q4) The following program should check if a number is a prime number. Debug the code.

def is_prime(n):
    for num in range(2, n):
        if num % n == 0:
            return False
    return True

numbers = np.arange(3, 21)
results = {}
for num in numbers:
    results[num] =is_prime(num)

print(f"Your results is {results}")
expected_result = {3: True, 4: False, 5: True, 6: False, 7: True, 8: False, 9: False, 10: False, 11: True, 12: False, 13: True, 14: False, 15: False, 16: False, 17: True, 18: False, 19: True, 20: False}
print(f"Expected result is: {expected_result}")
# Out:
# Your results is {np.int64(3): True, np.int64(4): True, np.int64(5): True, np.int64(6): True, np.int64(7): True, np.int64(8): True, np.int64(9): True, np.int64(10): True, np.int64(11): True, np.int64(12): True, np.int64(13): True, np.int64(14): True, np.int64(15): True, np.int64(16): True, np.int64(17): True, np.int64(18): True, np.int64(19): True, np.int64(20): True}
# Expected result is: {3: True, 4: False, 5: True, 6: False, 7: True, 8: False, 9: False, 10: False, 11: True, 12: False, 13: True, 14: False, 15: False, 16: False, 17: True, 18: False, 19: True, 20: False}

# %%
import numpy as np

def is_prime(n):
    for num in range(2, n):
        if n % num == 0:   # FIXED
            return False
    return True

numbers = np.arange(3, 21)
results = {}

for num in numbers:
    results[num] = is_prime(num)

print(f"Your results is {results}")

expected_result = {
    3: True, 4: False, 5: True, 6: False, 7: True, 8: False, 9: False,
    10: False, 11: True, 12: False, 13: True, 14: False, 15: False,
    16: False, 17: True, 18: False, 19: True, 20: False
}
print(f"Expected result is: {expected_result}")
# Out:
# Your results is {np.int64(3): True, np.int64(4): False, np.int64(5): True, np.int64(6): False, np.int64(7): True, np.int64(8): False, np.int64(9): False, np.int64(10): False, np.int64(11): True, np.int64(12): False, np.int64(13): True, np.int64(14): False, np.int64(15): False, np.int64(16): False, np.int64(17): True, np.int64(18): False, np.int64(19): True, np.int64(20): False}
# Expected result is: {3: True, 4: False, 5: True, 6: False, 7: True, 8: False, 9: False, 10: False, 11: True, 12: False, 13: True, 14: False, 15: False, 16: False, 17: True, 18: False, 19: True, 20: False}

# %%
#Q5) The following code uses stub functions to design the game. Complete the code.

def generate_random_num():
    """
    Generates a random integer between 1 and 100 (inclusive) for the user to guess.

    Arg: No input argument
    return: integer: The randomly generated number.
    """
    pass

def get_user_input():
    """
    This function asks the user to guess the number. Make sure that the number entered is an integer.
    Arg: No input argument
    return: the number.
    """
    while True:
        try:
            guess_num = int(input("Guess a number between 1 and 100: "))
            return guess_num
        except ValueError:
            print("That's not a valid integer. Please try again.")


def check_the_number(actual_num, guess_num):
    """
    This function checks if the actual number and guess number are the same.
    Arg: actual_num(integer): the number generated by random function
         guess_num (integer): the number user has guessed

    return: boolean : True if the numbers are the same. Else, False.
    """
    return False

def display_the_feedback(is_correct, chances):
    """
    This is a void function to print the feedback. If arg is True, display "bingo".
    Else, display "wrong guess" and indicates the number of chances left.

    Arg: is_correct(boolean): indicates if the guess is correct or not,
         chances (integer): indicates the number of chances left
    """
    pass

### Do not change the functions below ###
def guess_num_game():
    actual_num = generate_random_num()

    max_chances = 10
    for counter in range(1, max_chances+1):
        guess_num = get_user_input()
        is_correct = check_the_number(actual_num, guess_num)
        display_the_feedback(is_correct, max_chances - counter)
        if(is_correct):
            return "You did it! You won the game"

    return "You lost! Play one more time? "


def main():

    while True:
        win_lost_msg = guess_num_game()
        print(win_lost_msg)
        is_continue = int(input("Enter 1 to continue:"))
        if(not is_continue):
            return "Bye. Thanks for playing."

main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2274860322.py in <cell line: 0>()
#      68             return "Bye. Thanks for playing."
#      69
# ---> 70 main()
#
# /tmp/ipython-input-2274860322.py in main()
#      62
#      63     while True:
# ---> 64         win_lost_msg = guess_num_game()
#      65         print(win_lost_msg)
#      66         is_continue = int(input("Enter 1 to continue:"))
#
# /tmp/ipython-input-2274860322.py in guess_num_game()
#      50     max_chances = 10
#      51     for counter in range(1, max_chances+1):
# ---> 52         guess_num = get_user_input()
#      53         is_correct = check_the_number(actual_num, guess_num)
#      54         display_the_feedback(is_correct, max_chances - counter)
#
# /tmp/ipython-input-2274860322.py in get_user_input()
#      18     while True:
#      19         try:
# ---> 20             guess_num = int(input("Guess a number between 1 and 100: "))
#      21             return guess_num
#      22         except ValueError:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import numpy as np

def generate_random_num():
    """
    Generates a random integer between 1 and 100 (inclusive) for the user to guess.
    """
    return np.random.randint(1, 101)


def get_user_input():
    """
    This function asks the user to guess the number. Make sure that the number entered is an integer.
    """
    while True:
        try:
            guess_num = int(input("Guess a number between 1 and 100: "))
            return guess_num
        except ValueError:
            print("That's not a valid integer. Please try again.")


def check_the_number(actual_num, guess_num):
    """
    Checks if the actual number and guess number are the same.
    """
    return actual_num == guess_num


def display_the_feedback(is_correct, chances):
    """
    Prints feedback based on the guess result.
    """
    if is_correct:
        print("🎉 Bingo!")
    else:
        print(f"❌ Wrong guess. Chances left: {chances}")
